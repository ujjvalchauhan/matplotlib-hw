# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data_to_load = pd.read_csv("data/city_data.csv")
ride_data_to_load = pd.read_csv("data/ride_data.csv")

# Combine the data into a single dataset
combined_ride_data = pd.merge(city_data_to_load, ride_data_to_load,how='outer', on='city')
combined_ride_data

# Display the data table for preview
# Out:
#                  city  driver_count   type                 date   fare  \
# 0         Richardfort            38  Urban  2018-02-24 08:40:38  13.93
# 1         Richardfort            38  Urban  2018-02-13 12:46:07  14.00
# 2         Richardfort            38  Urban  2018-02-16 13:52:19  17.92
# 3         Richardfort            38  Urban  2018-02-01 20:18:28  10.26
# 4         Richardfort            38  Urban  2018-04-17 02:26:37  23.00
# 5         Richardfort            38  Urban  2018-04-21 03:44:04   9.54
# 6         Richardfort            38  Urban  2018-02-03 00:14:26  29.04
# 7         Richardfort            38  Urban  2018-02-08 15:50:12  16.55
# 8         Richardfort            38  Urban  2018-04-03 15:07:34  40.77
# 9         Richardfort            38  Urban  2018-02-19 14:09:20  27.11
# 10        Richardfort            38  Urban  2018-04-22 03:06:56  39.74
# 11        Richardfort            38  Urban  2018-01-31 14:51:01  43.92
# ...

# %%
# Split up our data into groups based upon 'gender'
city_groups = combined_ride_data.groupby('city')

# Find out how many of each gender took bike trips
city_data = city_groups['city'].count()

# Drop the 'stoptime' row that is contained within our group
city_data = city_data.drop(city_data.index[4])
colors=['orange','blue','yellow']
city_data.set_xlabel("city")
city_data.set_ylabel("Number of Trips Taken"
city_data.scatter(x=city, y=fare, alpha=0.5, c=colors)
# Out:
#   File "<ipython-input-27-1c1f4b88bef3>", line 12
#     city_data.scatter(x=city, y=fare, alpha=0.5, c=colors)
#             ^
# SyntaxError: invalid syntax

# %%
g=combined_ride_data.groupby('city')
avg_data["fare average"]=g["fare"].mean()
# Out:
# city
# Amandaburgh             24.641667
# Barajasview             25.332273
# Barronchester           36.422500
# Bethanyland             32.956111
# Bradshawfurt            40.064000
# Brandonfort             35.437368
# Carriemouth             28.314444
# Christopherfurt         24.501852
# Colemanland             30.894545
# Davidfurt               31.995882
# Deanville               25.842632
# East Aaronbury          25.661111
# East Danielview         31.560588
# East Kaylahaven         23.757931
# East Kentstad           29.823077
# East Marymouth          30.835185
# Erikaland               24.906667
# Garzaport               24.123333
# Grahamburgh             25.221200
# Grayville               27.763333
# Harringtonfort          33.470000
# Huntermouth             28.993750
# Hurleymouth             25.891429
# Jerryton                25.649200
# Jessicaport             36.013333
# Johnton                 26.785714
# Joneschester            22.289600
# ...

# %%
new_ride_data = combined_ride_data.sort_values(["avg_data"], ascending=False)
new_ride_data.reset_index(inplace=True)
new_ride_data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-aac80c3bac38> in <module>()
# ----> 1 new_ride_data = g.sort_values(["avg_data"], ascending=False)
#       2 new_ride_data.reset_index(inplace=True)
#       3 new_ride_data
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
# ...

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

# Build the scatter plots for each city types

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
# Show Figure
plt.show()
